# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
pd.set_option('display.float_format', lambda x: f'{x:,.2f}')

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\practicanteit3\Documents\MBA\Exploracion de segmentos

# %%
df = pd.read_csv('Documents/MBA/processed/premium.csv', sep=';')
df_historial = pd.read_csv('Documents/MBA/raw/ConsumoMasivoFiltro.csv', sep=';',low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1102 entries, 0 to 1101
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cliente          1102 non-null   int64
#  1   frecuencia       1102 non-null   int64
#  2   recencia         1102 non-null   int64
#  3   ticket_promedio  1102 non-null   float64
#  4   ticket           1102 non-null   float64
#  5   cl_value         1102 non-null   float64
# dtypes: float64(3), int64(3)
# memory usage: 51.8 KB

# %%
X = df[['frecuencia', 'ticket_promedio','cl_value']]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Evaluamos de 2 a 10 clusters
rango_k = range(2, 11)
inercias = []
siluetas = []

for k in rango_k:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inercias.append(kmeans.inertia_)
    siluetas.append(silhouette_score(X_scaled, kmeans.labels_))

# Graficamos el Método del Codo y Silueta juntos
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Gráfico del Codo
ax1.plot(rango_k, inercias, marker='o', color='steelblue', linewidth=2)
ax1.set_title('Método del Codo', fontsize=14, fontweight='bold')
ax1.set_xlabel('Número de Clusters (K)')
ax1.set_ylabel('Inercia')
ax1.set_xticks(range(2, 11))
ax1.grid(True, alpha=0.3)

# Gráfico de Silueta
ax2.plot(rango_k, siluetas, marker='s', color='coral', linewidth=2)
ax2.set_title('Coeficiente de Silueta', fontsize=14, fontweight='bold')
ax2.set_xlabel('Número de Clusters (K)')
ax2.set_ylabel('Silhouette Score')
ax2.set_xticks(range(2, 11))
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Tabla resumen
print("\n📋 Resumen de resultados:")
print(f"{'K':>3} | {'Inercia':>12} | {'Silueta':>8}")
print("-" * 30)
for k, iner, sil in zip(rango_k, inercias, siluetas):
    print(f"{k:>3} | {iner:>12,.2f} | {sil:>8.4f}")
# Out:
# C:\Users\practicanteit3\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\practicanteit3\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\practicanteit3\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\practicanteit3\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\practicanteit3\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\practicanteit3\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\practicanteit3\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\practicanteit3\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\practicanteit3\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# 📋 Resumen de resultados:
#   K |      Inercia |  Silueta
# ------------------------------
#   2 |     2,250.08 |   0.6851
#   3 |     1,402.24 |   0.4223
#   4 |     1,020.26 |   0.3947
#   5 |       794.57 |   0.4013
#   6 |       638.86 |   0.4031
#   7 |       550.33 |   0.3829
#   8 |       473.22 |   0.3809
#   9 |       417.16 |   0.3874
#  10 |       381.68 |   0.3559

# %%
# Aplicamos KMeans con 3 clusters
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_scaled)
df['cluster'] = clusters


# Veamos cuántos clientes hay en cada grupo
print("Distribución de clientes por cluster:")
print(df['cluster'].value_counts().sort_index())
df_escalados = pd.DataFrame(X_scaled, columns=['frecuencia','ticket_promedio','cl_value'])
df_escalados['cluster'] = clusters
# Out:
# Distribución de clientes por cluster:
# cluster
# 0    714
# 1    363
# 2     25
# Name: count, dtype: int64
# C:\Users\practicanteit3\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(

# %%
# Calcular promedios por cluster
resumen = df.groupby('cluster')[['frecuencia', 'ticket_promedio', 'cl_value']].mean()
resumen['clientes'] = df.groupby('cluster')['cliente'].count()
display(resumen.describe())
display(resumen)


# Crear el barplot
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

colores = ['#2ecc71', '#e74c3c', '#3498db']
variables = ['frecuencia', 'ticket_promedio', 'cl_value']
titulos = ['Frecuencia Promedio', 'Ticket Promedio', 'CL Value Promedio']

for i, (var, titulo) in enumerate(zip(variables, titulos)):
    bars = axes[i].bar(
        resumen.index.astype(str),
        resumen[var],
        color=colores,
        edgecolor='black',
        alpha=0.85
    )
    
    # Agregar valores encima de cada barra
    for bar in bars:
        height = bar.get_height()
        axes[i].text(
            bar.get_x() + bar.get_width() / 2.,
            height,
            f'{height:,.0f}',
            ha='center',
            va='bottom',
            fontsize=11,
            fontweight='bold'
        )
    
    axes[i].set_title(titulo, fontsize=14, fontweight='bold')
    axes[i].set_xlabel('Cluster', fontsize=12)
    axes[i].set_ylabel(var, fontsize=12)
    axes[i].yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.0f}'))

plt.suptitle('Comparación de Clusters - df_bajo', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
#        frecuencia  ticket_promedio     cl_value  clientes
# count        3.00             3.00         3.00      3.00
# mean        46.82        81,363.37 3,792,145.94    367.33
# std         45.34        15,191.12 3,719,045.75    344.52
# min         19.64        65,404.84 1,269,389.00     25.00
# 25%         20.65        74,220.80 1,656,624.96    194.00
# 50%         21.66        83,036.75 2,043,860.92    363.00
# 75%         60.41        89,342.63 5,053,524.41    538.50
# max         99.16        95,648.51 8,063,187.90    714.00
#          frecuencia  ticket_promedio     cl_value  clientes
# cluster
# 0             19.64        65,404.84 1,269,389.00       714
# 1             21.66        95,648.51 2,043,860.92       363
# 2             99.16        83,036.75 8,063,187.90        25

# %%
from sklearn.decomposition import PCA

df = df.reset_index(drop=True)
df_escalados = df_escalados.reset_index(drop=True)

df_escalados = df_escalados.drop(columns=['pca1', 'pca2'], errors='ignore')

pca = PCA(n_components=2)

# ✅ Las 3 variables CORRECTAS sin repetir
X_pca = pca.fit_transform(X_scaled)

df['pca1'] = X_pca[:, 0]
df['pca2'] = X_pca[:, 1]

fig, ax = plt.subplots(figsize=(12, 8))

colores = ['#2ecc71', '#e74c3c', '#3498db']
nombres = ['Cluster 0', 'Cluster 1', 'Cluster 2']

for cluster in range(3):
    mask = df['cluster'] == cluster
    ax.scatter(df.loc[mask, 'pca1'],
               df.loc[mask, 'pca2'],
               c=colores[cluster],
               label=f'{nombres[cluster]} ({mask.sum():,} clientes)',
               alpha=0.4,
               s=15)

ax.set_xlabel('PCA 1', fontsize=12)
ax.set_ylabel('PCA 2', fontsize=12)
ax.set_title('Segmentación de Clientes - df_bajo (K=4) con PCA', fontsize=14)
ax.legend(fontsize=11)
plt.tight_layout()
plt.show()

# %%
info = pca.components_

info = pd.DataFrame(info, columns = ['frecuencia', 'ticket_promedio','cl_value'])
info
# Out:
#    frecuencia  ticket_promedio  cl_value
# 0        0.68             0.20      0.71
# 1       -0.28             0.96     -0.01

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

pca1=PCA(n_components=3)

X_pca1 = pca1.fit_transform(df[['frecuencia','ticket_promedio','cl_value']])


fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection='3d')

colores = ['#2ecc71', '#e74c3c', '#3498db','#3412f1']
nombres = ['Cluster 0', 'Cluster 1', 'Cluster 2']

for cluster in range(3):
    mask = df['cluster'] == cluster
    ax.scatter(df.loc[mask, 'frecuencia'],
               df.loc[mask, 'ticket_promedio'],
               df.loc[mask, 'cl_value'],
               c=colores[cluster],
               label=f'{nombres[cluster]} ({mask.sum():,} clientes)',
               alpha=0.4,
               s=15)

ax.set_xlabel('Frecuencia', fontsize=11, labelpad=10)
ax.set_ylabel('Ticket Promedio', fontsize=11, labelpad=10)
ax.set_zlabel('CL Value', fontsize=11, labelpad=10)
ax.set_title('Segmentación 3D - df_bajo (K=3)', fontsize=14)

# Formato de números con comas
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.0f}'))
ax.zaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.0f}'))

ax.legend(fontsize=11, loc='upper left')

# Ángulo de visualización
ax.view_init(elev=25, azim=45)

plt.tight_layout()
# Agrega esta línea ANTES de plt.show()

# Ángulo 1: Vista elevada
ax.view_init(elev=30, azim=45)

# Ángulo 2: Vista lateral
ax.view_init(elev=15, azim=120)

# Ángulo 3: Vista frontal
ax.view_init(elev=0, azim=0)

# Ángulo 4: Vista de pájaro (desde arriba)
ax.view_init(elev=90, azim=0)

# Ángulo 5: Vista diagonal
ax.view_init(elev=20, azim=225)

plt.show()

# %%
df[df['cluster']==0].describe()
# Out:
#                cliente  frecuencia  recencia  ticket_promedio        ticket  \
# count           714.00      714.00    714.00           714.00        714.00
# mean    431,971,389.02       19.64     25.09        65,404.84  5,164,449.52
# std     466,175,461.98       11.39     21.82         7,492.93  5,623,280.00
# min         608,474.00        2.00      0.00        55,235.16    122,518.40
# 25%      39,981,215.75       11.00      8.00        58,683.59  1,647,515.42
# 50%      71,595,044.00       18.00     16.00        64,038.83  3,361,668.63
# 75%     901,972,638.00       27.00     41.00        70,863.74  6,328,863.24
# max   1,234,990,040.00       68.00     84.00        86,019.60 48,037,341.53
#
#           cl_value  cluster   pca1   pca2
# count       714.00   714.00 714.00 714.00
# mean  1,269,389.00     0.00  -0.43  -0.55
# std     719,938.99     0.00   0.80   0.50
# min     111,093.10     0.00  -1.83  -1.68
# 25%     721,235.59     0.00  -1.04  -0.92
# 50%   1,184,582.59     0.00  -0.53  -0.62
# 75%   1,752,395.28     0.00   0.10  -0.21
# max   4,250,056.32     0.00   2.91   0.90

# %%
df.head()
# Out:
#    cliente  frecuencia  recencia  ticket_promedio        ticket     cl_value  \
# 0   608474          33         0        64,228.93  7,707,472.00 2,119,554.80
# 1   647406          32         8        59,211.64 13,204,194.64 1,894,772.32
# 2   722447          13        58       106,997.74  7,703,837.62 1,390,970.68
# 3  1228994          30        13        57,481.99  6,725,392.93 1,724,459.73
# 4  2483269          28         8        61,849.65  3,587,279.63 1,731,790.17
#
#    cluster  pca1  pca2
# 0        0  0.51 -0.84
# 1        0  0.30 -1.11
# 2        1 -0.13  1.93
# 3        0  0.11 -1.17
# 4        0  0.09 -0.89

# %% [markdown]
# ## Analisis de canasta de compra

# %%
df_mba = pd.merge(df_historial, df, on='cliente', how = 'inner')
df_mba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111819 entries, 0 to 111818
# Data columns (total 39 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   factura              111819 non-null  object
#  1   cliente              111819 non-null  int64
#  2   nombrecliente        111819 non-null  object
#  3   tipocliente          111819 non-null  object
#  4   fechafactura         111819 non-null  object
#  5   referencia           111819 non-null  object
#  6   nombrereferencia     111819 non-null  object
#  7   cantidad             111819 non-null  float64
#  8   preciounitario       111819 non-null  float64
#  9   costounitario        111819 non-null  float64
#  10  montoventa           111819 non-null  float64
#  11  montoventapesos      111819 non-null  float64
#  12  costoventapesos      111819 non-null  float64
#  13  valordescuento       111819 non-null  float64
#  14  unidadnegocios       111819 non-null  int64
#  15  centrocostos         111819 non-null  int64
#  16  troevendedor         111753 non-null  float64
#  17  troenombrevendedor   111753 non-null  object
#  18  grouptat             111805 non-null  object
#  19  lineatat             111819 non-null  object
#  20  tro_e_marca          111787 non-null  object
#  21  obsequio             111819 non-null  int64
#  22  ruta                 111791 non-null  float64
#  23  porcentajedescuento  111143 non-null  float64
#  24  margenpesos          111819 non-null  float64
#  25  porcentajemargen     111143 non-null  float64
#  26  zona                 111783 non-null  object
#  27  ciclo                111783 non-null  object
#  28  zona_pais            111819 non-null  object
#  29  centro_costos        111819 non-null  object
#  30  canal                111819 non-null  object
#  31  frecuencia           111819 non-null  int64
#  32  recencia             111819 non-null  int64
#  33  ticket_promedio      111819 non-null  float64
#  34  ticket               111819 non-null  float64
#  35  cl_value             111819 non-null  float64
#  36  cluster              111819 non-null  int32
#  37  pca1                 111819 non-null  float64
#  38  pca2                 111819 non-null  float64
# dtypes: float64(17), int32(1), int64(6), object(15)
# memory usage: 32.8+ MB

# %%
df_mba.head()
# Out:
#          factura     cliente                 nombrecliente tipocliente  \
# 0  HHME001172025    39409734  MARY CIELO TRUJILLO GONZALEZ  TAT CENTRO
# 1  HHME001182392   811030335         LUCES Y SONIDO S.A.S.  TAT CENTRO
# 2  HHME001302777  1026155250       JUAN DAVID PINEDA HENAO  TAT CENTRO
# 3  HHME001197103    71982762          ENRIQUE DIAZ ESCOBAR  TAT CENTRO
# 4  HHME001399092    43261631          ANA LIRIA CANO MANCO  TAT CENTRO
#
#               fechafactura     referencia  \
# 0  2024-05-15 00:00:00.000  GP250AAHC-C2N
# 1  2024-06-05 00:00:00.000  GP250AAHC-C2N
# 2  2025-01-23 00:00:00.000   ALC013654-12
# 3  2024-07-03 00:00:00.000   ALC013654-12
# 4  2025-07-22 00:00:00.000   ALC013654-12
#
#                                     nombrereferencia  cantidad  \
# 0  PILA RECARGABLE GP NIMH AA 1.2V 2500 MAH BLIST...      2.00
# 1  PILA RECARGABLE GP NIMH AA 1.2V 2500 MAH BLIST...      6.00
# 2                      ALPINO COLORES BORRABLES  X12      4.00
# 3                      ALPINO COLORES BORRABLES  X12      5.00
# 4                      ALPINO COLORES BORRABLES  X12      3.00
#
#    preciounitario  costounitario  ...  centro_costos  canal  frecuencia  \
# 0       26,512.61       8,697.97  ...       Apartado    TAT          34
# 1       26,512.61       8,697.97  ...       Apartado    TAT          53
# 2       14,621.85       5,413.89  ...       Apartado    TAT          13
# 3       13,907.56       5,413.89  ...       Apartado    TAT          25
# 4       14,621.85       5,413.89  ...       Apartado    TAT          19
#
#    recencia  ticket_promedio        ticket     cl_value cluster  pca1  pca2
# 0        15        77,279.23 23,879,282.37 2,627,493.85       1  0.96 -0.11
# 1         2        80,236.05 42,364,635.45 4,252,510.76       1  2.57 -0.26
# 2        43        98,948.81  2,968,464.30 1,286,334.53       1 -0.28  1.48
# 3         7        80,431.08  6,997,504.37 2,010,777.12       1  0.34  0.22
# 4        40        66,716.13  8,339,516.60 1,267,606.52       0 -0.44 -0.46
#
# [5 rows x 39 columns]

# %%
basket = df_mba.groupby('factura')['referencia'].apply(list)
indices = basket.index.tolist()

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,association_rules

te = TransactionEncoder()
te_ary = te.fit(basket).transform(basket)
df_mba_analysis = pd.DataFrame(te_ary,columns = te.columns_, index = indices )

# %%
df_mba_analysis = apriori(df_mba_analysis, min_support= 0.1, use_colnames=True)
df_mba_analysis['productos'] = df_mba_analysis['itemsets'].apply( lambda x: len(x)) 
df_mba_analysis.sort_values(by='support', ascending=False)
# Out:
#     support                                     itemsets  productos
# 9      0.37                                (TRAALR6ALB2)          1
# 6      0.31                              (TRAAALR03ALB2)          1
# 16     0.24                 (TRAALR6ALB2, TRAAALR03ALB2)          2
# 10     0.23                                (TRAAR6EHDB2)          1
# 11     0.22                                (TRAAR6EHDR1)          1
# 14     0.20                             (TRDR20RJBLK180)          1
# 7      0.19                              (TRAAAR03EHDB2)          1
# 4      0.18                                     (SLBSLE)          1
# 19     0.17                 (TRAAAR03EHDB2, TRAAR6EHDB2)          2
# 12     0.15                                (TRDLR20ALB2)          1
# 21     0.15                   (TRAALR6ALB2, TRAAR6EHDB2)          2
# 8      0.14                             (TRAAAR03EHDBLK)          1
# 13     0.14                                 (TRDR20RJB2)          1
# 1      0.14                        (SBLEDA6012WM10CLBLK)          1
# 0      0.13                                      (CPSCL)          1
# 18     0.13                 (TRAAAR03EHDB2, TRAALR6ALB2)          2
# 17     0.13                 (TRAAALR03ALB2, TRAAR6EHDB2)          2
# 2      0.13                         (SBLEDA607WM10CLBLK)          1
# 5      0.13                                  (SLTMPSLB1)          1
# 15     0.12               (TRAAAR03EHDB2, TRAAALR03ALB2)          2
# 25     0.12    (TRAAAR03EHDB2, TRAALR6ALB2, TRAAR6EHDB2)          3
# 3      0.12                         (SBLEDA609WM10CLBLK)          1
# 24     0.11    (TRAALR6ALB2, TRAAALR03ALB2, TRAAR6EHDB2)          3
# 23     0.11  (TRAAAR03EHDB2, TRAAALR03ALB2, TRAAR6EHDB2)          3
# 20     0.11                (TRAAR6EHDR1, TRAAAR03EHDBLK)          2
# 22     0.10  (TRAAAR03EHDB2, TRAALR6ALB2, TRAAALR03ALB2)          3

# %%
reglas = association_rules(df_mba_analysis,metric='confidence', min_threshold=0.5)

# %%
reglas
# Out:
#                        antecedents                   consequents  \
# 0                  (TRAAAR03EHDB2)               (TRAAALR03ALB2)
# 1                    (TRAALR6ALB2)               (TRAAALR03ALB2)
# 2                  (TRAAALR03ALB2)                 (TRAALR6ALB2)
# 3                    (TRAAR6EHDB2)               (TRAAALR03ALB2)
# 4                  (TRAAAR03EHDB2)                 (TRAALR6ALB2)
# 5                  (TRAAAR03EHDB2)                 (TRAAR6EHDB2)
# 6                    (TRAAR6EHDB2)               (TRAAAR03EHDB2)
# 7                 (TRAAAR03EHDBLK)                 (TRAAR6EHDR1)
# 8                    (TRAAR6EHDB2)                 (TRAALR6ALB2)
# 9     (TRAAAR03EHDB2, TRAALR6ALB2)               (TRAAALR03ALB2)
# 10  (TRAAAR03EHDB2, TRAAALR03ALB2)                 (TRAALR6ALB2)
# 11                 (TRAAAR03EHDB2)  (TRAALR6ALB2, TRAAALR03ALB2)
# 12  (TRAAAR03EHDB2, TRAAALR03ALB2)                 (TRAAR6EHDB2)
# 13    (TRAAAR03EHDB2, TRAAR6EHDB2)               (TRAAALR03ALB2)
# 14    (TRAAALR03ALB2, TRAAR6EHDB2)               (TRAAAR03EHDB2)
# 15                 (TRAAAR03EHDB2)  (TRAAALR03ALB2, TRAAR6EHDB2)
# 16      (TRAALR6ALB2, TRAAR6EHDB2)               (TRAAALR03ALB2)
# 17    (TRAAALR03ALB2, TRAAR6EHDB2)                 (TRAALR6ALB2)
# 18                   (TRAAR6EHDB2)  (TRAALR6ALB2, TRAAALR03ALB2)
# 19    (TRAAAR03EHDB2, TRAALR6ALB2)                 (TRAAR6EHDB2)
# 20    (TRAAAR03EHDB2, TRAAR6EHDB2)                 (TRAALR6ALB2)
# 21      (TRAALR6ALB2, TRAAR6EHDB2)               (TRAAAR03EHDB2)
# 22                 (TRAAAR03EHDB2)    (TRAALR6ALB2, TRAAR6EHDB2)
# 23                   (TRAAR6EHDB2)  (TRAAAR03EHDB2, TRAALR6ALB2)
#
#     antecedent support  consequent support  support  confidence  lift  \
# 0                 0.19                0.31     0.12        0.63  2.07
# 1                 0.37                0.31     0.24        0.65  2.12
# 2                 0.31                0.37     0.24        0.79  2.12
# 3                 0.23                0.31     0.13        0.58  1.89
# 4                 0.19                0.37     0.13        0.68  1.84
# 5                 0.19                0.23     0.17        0.88  3.89
# 6                 0.23                0.19     0.17        0.75  3.89
# 7                 0.14                0.22     0.11        0.74  3.32
# 8                 0.23                0.37     0.15        0.67  1.82
# 9                 0.13                0.31     0.10        0.80  2.61
# 10                0.12                0.37     0.10        0.86  2.31
# 11                0.19                0.24     0.10        0.54  2.26
# 12                0.12                0.23     0.11        0.90  4.00
# 13                0.17                0.31     0.11        0.65  2.13
# 14                0.13                0.19     0.11        0.84  4.38
# 15                0.19                0.13     0.11        0.57  4.38
# 16                0.15                0.31     0.11        0.74  2.43
# 17                0.13                0.37     0.11        0.87  2.34
# 18                0.23                0.24     0.11        0.50  2.09
# 19                0.13                0.23     0.12        0.92  4.07
# 20                0.17                0.37     0.12        0.71  1.92
# 21                0.15                0.19     0.12        0.79  4.11
# 22                0.19                0.15     0.12        0.63  4.11
# 23                0.23                0.13     0.12        0.53  4.07
#
#     representativity  leverage  conviction  zhangs_metric  jaccard  certainty  \
# 0               1.00      0.06        1.89           0.64     0.32       0.47
# 1               1.00      0.13        1.97           0.84     0.55       0.49
# 2               1.00      0.13        2.95           0.76     0.55       0.66
# 3               1.00      0.06        1.64           0.61     0.32       0.39
# 4               1.00      0.06        1.98           0.56     0.30       0.49
# 5               1.00      0.12        6.21           0.92     0.67       0.84
# 6               1.00      0.12        3.19           0.96     0.67       0.69
# 7               1.00      0.07        3.02           0.82     0.41       0.67
# 8               1.00      0.07        1.93           0.58     0.34       0.48
# 9               1.00      0.06        3.43           0.71     0.31       0.71
# 10              1.00      0.06        4.49           0.65     0.27       0.78
# 11              1.00      0.06        1.67           0.69     0.32       0.40
# 12              1.00      0.08        7.85           0.85     0.46       0.87
# 13              1.00      0.06        1.99           0.64     0.30       0.50
# 14              1.00      0.08        5.10           0.89     0.51       0.80
# 15              1.00      0.08        2.02           0.96     0.51       0.51
# 16              1.00      0.07        2.71           0.69     0.33       0.63
# 17              1.00      0.06        4.81           0.66     0.29       0.79
# 18              1.00      0.06        1.53           0.67     0.32       0.34
# 19              1.00      0.09        9.29           0.87     0.51       0.89
# 20              1.00      0.06        2.20           0.58     0.29       0.55
# 21              1.00      0.09        3.85           0.89     0.54       0.74
# 22              1.00      0.09        2.26           0.94     0.54       0.56
# 23              1.00      0.09        1.86           0.97     0.51       0.46
#
#     kulczynski
# 0         0.51
# 1         0.72
# 2         0.72
# 3         0.50
# 4         0.52
# 5         0.81
# 6         0.81
# 7         0.61
# 8         0.54
# 9         0.57
# 10        0.57
# 11        0.49
# 12        0.69
# 13        0.50
# 14        0.71
# 15        0.71
# 16        0.56
# 17        0.59
# 18        0.49
# 19        0.72
# 20        0.52
# 21        0.71
# 22        0.71
# 23        0.72

# %%
df_mba.to_csv('Documents/MBA/reglas/segmento_premium/Basket.csv',sep=';')
reglas.to_csv('Documents/MBA/reglas/segmento_premium/reglas.csv',sep=';')
