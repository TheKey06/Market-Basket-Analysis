# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: f'{x:,.2f}')

# %%
df = pd.read_csv('ConsumoMasivoFiltro.csv', sep= ';', low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3803199 entries, 0 to 3803198
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   factura              object
#  1   cliente              int64
#  2   nombrecliente        object
#  3   tipocliente          object
#  4   fechafactura         object
#  5   referencia           object
#  6   nombrereferencia     object
#  7   cantidad             float64
#  8   preciounitario       float64
#  9   costounitario        float64
#  10  montoventa           float64
#  11  montoventapesos      float64
#  12  costoventapesos      float64
#  13  valordescuento       float64
#  14  unidadnegocios       int64
#  15  centrocostos         int64
#  16  troevendedor         float64
#  17  troenombrevendedor   object
#  18  grouptat             object
#  19  lineatat             object
#  20  tro_e_marca          object
#  21  obsequio             int64
#  22  ruta                 float64
#  23  porcentajedescuento  float64
#  24  margenpesos          float64
#  25  porcentajemargen     float64
#  26  zona                 object
#  27  ciclo                object
#  28  zona_pais            object
#  29  centro_costos        object
#  30  canal                object
# dtypes: float64(12), int64(4), object(15)
# memory usage: 899.5+ MB

# %%
df[['ruta', 'zona', 'canal', 'centro_costos','centrocostos','unidadnegocios','troevendedor']] = df[['ruta', 'zona', 'canal', 'centro_costos','centrocostos','unidadnegocios','troevendedor',]].astype(object)
df['fechafactura'] = pd.to_datetime(df['fechafactura'])
df['cliente'] = df['cliente'].astype(int)

# %%
df = df[df['obsequio'] ==0]
# Reemplazos
df['referencia'] = df['referencia'].str.replace('TRAAAR03EHDJBLK', 'TRAAAR03EHDBLK', regex=False)
df['referencia'] = df['referencia'].str.replace('TRAAR6EHDJBLK', 'TRAAR6EHDR1', regex=False)

# Relleno de nulos
df.loc[df['canal'].isnull(), 'canal'] = "TAT"
df.loc[df['zona_pais'].isnull(), 'zona_pais'] = "ZONA CENTRO"
df.loc[df['ciclo'].isnull(), 'ciclo'] = "NA"
df.loc[df['zona'].isnull(), 'zona'] = "NA"
df.loc[df['porcentajemargen'].isnull(), 'porcentajemargen'] = 0
df.loc[df['porcentajedescuento'].isnull(), 'porcentajedescuento'] = 0
df.loc[df['ruta'].isnull(), 'ruta'] = "9999"
df.loc[df['tro_e_marca'].isnull(), 'tro_e_marca'] = "OTROS"
df.loc[df['lineatat'].isnull(), 'lineatat'] = "OTROS"
df.loc[df['grouptat'].isnull(), 'grouptat'] = "OTROS"
df.loc[df['troenombrevendedor'].isnull(), 'troenombrevendedor'] = "No Aplica"
df.loc[df['troevendedor'].isnull(), 'troevendedor'] = '9999'
df.loc[df['centro_costos'].isnull(), 'centro_costos'] = "Medellín"

# %%
df =df[(df['canal']=='TAT') ]

# %%
df[df['cliente']==901256880][['montoventapesos','cantidad','zona']].sum()
# Out:
# montoventapesos                      -3,674.01
# cantidad                                -12.00
# zona               702207906207702207702702207
# dtype: object

# %%
def obtener_moda(serie):
    return serie.mode()[0]

df_zonas = df.groupby('cliente')['zona'].agg(obtener_moda)

# %%
df_zonas.columns = ['cliente','zona']

# %%
df_zonas = df_zonas.reset_index()

# %%
df_zonas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105939 entries, 0 to 105938
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   cliente  105939 non-null  int64
#  1   zona     105939 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.6+ MB

# %%
df_zonas = df_zonas[(df_zonas['zona'].str.startswith('1')) |  (df_zonas['zona'].str.startswith('2'))]

# %%
df_modificado = pd.merge(df, df_zonas, on = 'cliente', how = 'inner')

# %%
df_modificado.describe().T
# Out:
#                          count                           mean  \
# cliente             940,527.00                 364,050,203.81
# fechafactura            940527  2025-05-04 07:46:42.350171904
# cantidad            940,527.00                          25.58
# preciounitario      940,527.00                       4,039.07
# costounitario       940,527.00                       1,771.36
# montoventa          940,527.00                      43,607.11
# montoventapesos     940,527.00                      43,607.11
# costoventapesos     940,527.00                      19,148.80
# valordescuento      940,527.00                       1,566.50
# obsequio            940,527.00                           0.00
# porcentajedescuento 940,527.00                           0.01
# margenpesos         940,527.00                      24,458.31
# porcentajemargen    940,527.00                           0.55
#
#                                      min                  25%  \
# cliente                       295,436.00        32,304,581.00
# fechafactura         2024-05-03 00:00:00  2024-10-29 00:00:00
# cantidad                       -2,880.00                 5.00
# preciounitario                      0.00               882.35
# costounitario                     181.70               463.17
# montoventa                 -5,269,495.51            16,806.80
# montoventapesos            -5,269,495.51            16,806.80
# costoventapesos            -2,193,623.42             7,705.70
# valordescuento               -300,630.15                 0.00
# obsequio                            0.00                 0.00
# porcentajedescuento                 0.00                 0.00
# margenpesos                -3,075,872.09             8,686.57
# porcentajemargen                  -22.89                 0.47
#
#                                      50%                  75%  \
# cliente                    70,662,555.00       901,622,322.00
# fechafactura         2025-05-12 00:00:00  2025-11-05 00:00:00
# cantidad                           12.00                25.00
# preciounitario                  2,352.94             3,781.51
# costounitario                     938.38             1,574.80
# montoventa                     25,210.20            39,495.80
# montoventapesos                25,210.20            39,495.80
# costoventapesos                10,623.75            17,717.80
# valordescuento                      0.00                 0.00
# obsequio                            0.00                 0.00
# porcentajedescuento                 0.00                 0.00
# margenpesos                    13,943.53            25,440.35
# porcentajemargen                    0.56                 0.63
#
#                                      max            std
# cliente                10,483,221,957.00 488,465,011.84
# fechafactura         2026-05-06 00:00:00            NaN
# cantidad                       14,400.00          99.61
# preciounitario              1,651,818.33       8,300.10
# costounitario               1,022,250.31       4,139.15
# montoventa                 36,847,040.40     125,654.19
# montoventapesos            36,847,040.40     125,654.19
# costoventapesos            14,843,385.95      57,025.47
# valordescuento              5,505,879.60      17,953.89
# obsequio                            0.00           0.00
# porcentajedescuento                 0.97           0.03
# margenpesos                22,003,654.45      72,481.56
# porcentajemargen                    0.81           0.15

# %%
df_modificado = df_modificado.drop(columns =['zona_x'])
df_modificado = df_modificado.rename(columns = {'zona_y':'zona'})
df_modificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940527 entries, 0 to 940526
# Data columns (total 31 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   factura              940527 non-null  object
#  1   cliente              940527 non-null  int64
#  2   nombrecliente        940527 non-null  object
#  3   tipocliente          940527 non-null  object
#  4   fechafactura         940527 non-null  datetime64[ns]
#  5   referencia           940527 non-null  object
#  6   nombrereferencia     940527 non-null  object
#  7   cantidad             940527 non-null  float64
#  8   preciounitario       940527 non-null  float64
#  9   costounitario        940527 non-null  float64
#  10  montoventa           940527 non-null  float64
#  11  montoventapesos      940527 non-null  float64
#  12  costoventapesos      940527 non-null  float64
#  13  valordescuento       940527 non-null  float64
#  14  unidadnegocios       940527 non-null  object
#  15  centrocostos         940527 non-null  object
#  16  troevendedor         940527 non-null  object
#  17  troenombrevendedor   940527 non-null  object
#  18  grouptat             940527 non-null  object
#  19  lineatat             940527 non-null  object
#  20  tro_e_marca          940527 non-null  object
#  21  obsequio             940527 non-null  int64
#  22  ruta                 940527 non-null  object
#  23  porcentajedescuento  940527 non-null  float64
#  24  margenpesos          940527 non-null  float64
#  25  porcentajemargen     940527 non-null  float64
#  26  ciclo                940527 non-null  object
#  27  zona_pais            940527 non-null  object
#  28  centro_costos        940527 non-null  object
#  29  canal                940527 non-null  object
#  30  zona                 940527 non-null  object
# dtypes: datetime64[ns](1), float64(10), int64(2), object(18)
# memory usage: 222.4+ MB

# %%
df_modificado.describe()
# Out:
#                 cliente                   fechafactura   cantidad  \
# count        940,527.00                         940527 940,527.00
# mean     364,050,203.81  2025-05-04 07:46:42.350171904      25.58
# min          295,436.00            2024-05-03 00:00:00  -2,880.00
# 25%       32,304,581.00            2024-10-29 00:00:00       5.00
# 50%       70,662,555.00            2025-05-12 00:00:00      12.00
# 75%      901,622,322.00            2025-11-05 00:00:00      25.00
# max   10,483,221,957.00            2026-05-06 00:00:00  14,400.00
# std      488,465,011.84                            NaN      99.61
#
#        preciounitario  costounitario    montoventa  montoventapesos  \
# count      940,527.00     940,527.00    940,527.00       940,527.00
# mean         4,039.07       1,771.36     43,607.11        43,607.11
# min              0.00         181.70 -5,269,495.51    -5,269,495.51
# 25%            882.35         463.17     16,806.80        16,806.80
# 50%          2,352.94         938.38     25,210.20        25,210.20
# 75%          3,781.51       1,574.80     39,495.80        39,495.80
# max      1,651,818.33   1,022,250.31 36,847,040.40    36,847,040.40
# std          8,300.10       4,139.15    125,654.19       125,654.19
#
#        costoventapesos  valordescuento   obsequio  porcentajedescuento  \
# count       940,527.00      940,527.00 940,527.00           940,527.00
# mean         19,148.80        1,566.50       0.00                 0.01
# min      -2,193,623.42     -300,630.15       0.00                 0.00
# 25%           7,705.70            0.00       0.00                 0.00
# 50%          10,623.75            0.00       0.00                 0.00
# 75%          17,717.80            0.00       0.00                 0.00
# max      14,843,385.95    5,505,879.60       0.00                 0.97
# std          57,025.47       17,953.89       0.00                 0.03
#
#         margenpesos  porcentajemargen
# count    940,527.00        940,527.00
# mean      24,458.31              0.55
# min   -3,075,872.09            -22.89
# 25%        8,686.57              0.47
# 50%       13,943.53              0.56
# 75%       25,440.35              0.63
# max   22,003,654.45              0.81
# std       72,481.56              0.15

# %%
df_modificado.to_csv('Antioquia.csv', index = False, sep = ';', encoding = 'utf-8')
