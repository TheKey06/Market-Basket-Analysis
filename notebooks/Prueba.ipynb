# %%
import pandas as pd

# %%
df = pd.read_parquet('../raw/Antioquia.parquet')

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952033 entries, 0 to 952032
# Data columns (total 31 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   factura              952033 non-null  object
#  1   cliente              952033 non-null  int64
#  2   nombrecliente        952033 non-null  object
#  3   tipocliente          952033 non-null  object
#  4   fechafactura         952033 non-null  datetime64[ns]
#  5   referencia           952033 non-null  object
#  6   nombrereferencia     952033 non-null  object
#  7   cantidad             952033 non-null  float64
#  8   preciounitario       952033 non-null  float64
#  9   costounitario        952033 non-null  float64
#  10  montoventa           952033 non-null  float64
#  11  montoventapesos      952033 non-null  float64
#  12  costoventapesos      952033 non-null  float64
#  13  valordescuento       952033 non-null  float64
# ...
